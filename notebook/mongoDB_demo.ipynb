# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# df should be converted into dict before we push it to mongodb

data = df.to_dict(orient='records')
# data

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb://kuldeepsvts:Charchita123@ac-g5a51ks-shard-00-00.pkfsi0s.mongodb.net:27017,ac-g5a51ks-shard-00-01.pkfsi0s.mongodb.net:27017,ac-g5a51ks-shard-00-02.pkfsi0s.mongodb.net:27017/?replicaSet=atlas-11yyj5-shard-0&ssl=true&authSource=admin&retryWrites=true&w=majority&appName=Cluster0"
# above, either remove your credentials or delete the mongoDB resource bofore pushing it to github.

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
# Uploading data to MongoDB
rec = collection.insert_many(data)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[46], line 2
#       1 # Uploading data to MongoDB
# ----> 2 rec = collection.insert_many(data)
#
# File c:\Users\91816\Desktop\MLOps\Vehicle_Insurance\vehicle\Lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File c:\Users\91816\Desktop\MLOps\Vehicle_Insurance\vehicle\Lib\site-packages\pymongo\synchronous\collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
# ...

# %%
# Load back data from mongodb

df = pd.DataFrame(list(collection.find()))
df.head(2)

# %%
## If you are getting timeout issue

# import certifi
# client = pymongo.MongoClient(CONNECTION_URL, tlsCAFile=certifi.where())
# # TO CREATE THE DATABASE
# data_base = client[DB_NAME]
# collection = data_base[COLLECTION_NAME]
# # TO INSERT DATA INTO THE COLLECTION
# rec = collection.insert_many(data)
